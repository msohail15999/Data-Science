# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:/Users/LENOVO/Downloads/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
x_train,x_test,y_train,y_test = train_test_split(x,target,test,size=0-2,random_state=10)

model.RandomForestClassifier()
model.fit(x_train,y_train)
predmodel.predict(x_test)
metrics.accuracy_score(pred,y_test)
metrics.confusion_matrix(pred,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-69da8bba0303> in <module>
#       5 from sklearn.linear_model import LogisticRegression
#       6 from sklearn.svm import SVC
# ----> 7 x_train,x_test,y_train,y_test = train_test_split(x,target,test,size=0-2,random_state=10)
#       8
#       9 model.RandomForestClassifier()
#
# NameError: name 'x' is not defined

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9444b7c94bf5> in <module>
# ----> 1 df.groupby(df["Survived"]).count()
#
# NameError: name 'df' is not defined

# %%
sortbymale = df.sort_values('Sex')
print(sortbymale.head())
# Out:
#      PassengerId  Survived  Pclass  \
# 383          384         1       1
# 218          219         1       1
# 609          610         1       1
# 216          217         1       3
# 215          216         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 383  Holverson, Mrs. Alexander Oskar (Mary Aline To...  female  35.0      1
# 218                              Bazzani, Miss. Albina  female  32.0      0
# 609                          Shutes, Miss. Elizabeth W  female  40.0      0
# 216                             Honkanen, Miss. Eliina  female  27.0      0
# 215                            Newell, Miss. Madeleine  female  31.0      1
#
#      Parch            Ticket      Fare Cabin Embarked
# 383      0            113789   52.0000   NaN        S
# 218      0             11813   76.2917   D15        C
# 609      0          PC 17582  153.4625  C125        S
# 216      0  STON/O2. 3101283    7.9250   NaN        S
# ...

# %%
df[(df['Sex']== 'male') & (df['Survived']== 1)].sum()
# Out:
# PassengerId                                                51854
# Survived                                                     109
# Pclass                                                       220
# Name           Williams, Mr. Charles EugeneBeesley, Mr. Lawre...
# Sex            malemalemalemalemalemalemalemalemalemalemalema...
# Age                                                      2536.67
# SibSp                                                         42
# Parch                                                         39
# Ticket         2443732486981137882677199472661160124873834577...
# Fare                                                     4449.54
# Embarked       SSSCSCSSSCSCSSSSSSSCCSSSSSSSSSSSQSSSSCSSSSSSSS...
# dtype: object

# %%
import seaborn as sns

# %%
import sklearn.datasets import #tab here to get databases
# Out:
#   File "<ipython-input-6-81a37d510225>", line 1
#     import sklearn.datasets import #tab here to get databases
#                                  ^
# SyntaxError: invalid syntax

# %%
df[(df['Sex']== 'female') & (df['Survived']== 1)].sum()
# Out:
# PassengerId                                               100120
# Survived                                                     233
# Pclass                                                       447
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex            femalefemalefemalefemalefemalefemalefemalefema...
# Age                                                         5683
# SibSp                                                        120
# Parch                                                        120
# Ticket         PC 17599STON/O2. 3101282113803347742237736PP 9...
# Fare                                                     12101.7
# dtype: object

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
sns.countplot(x="Survived" ,data=df)

# %%
sns.countplot(x="Pclass" ,data=df)

# %%
sns.countplot(x="Survived",hue="Sex" ,data=df)

# %%
df["Survived"][df["Sex"]=='male'].value_counts()
# Out:
# 0    468
# 1    109
# Name: Survived, dtype: int64

# %%
sns.countplot(x="Survived",hue="Pclass" ,data=df)

# %%
sns.countplot(x="Survived",hue="Pclass" ,data=df)

# %%
df["Age"].plot.hist(bins=20,histtype= 'stepfilled')

# %%
df["Fare"].plot.hist(bins=20,histtype= 'stepfilled')

# %%
df["Age"].plot.hist(bins=20,histtype= 'stepfilled')

# %%
df["Age"].plot.hist(bins=20)

# %%
sns.boxplot(x="Pclass",y="Age",data=df)

# %%
sns.boxplot(x="Pclass",y="Fare",data=df)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap="viridis")

# %%
df=df.drop(['Passengerid','Name','Siblings','TicketNo','Cabin','Porch'],axis='1')

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df1=df.drop[["PassengerId","Name","Siblings","Ticketno","Cabin","Parch"], axis=1]
# Out:
#   File "<ipython-input-58-80e133bd8b4a>", line 1
#     df1=df.drop[["PassengerId","Name","Siblings","Ticketno","Cabin","Parch"], axis=1]
#                                                                                   ^
# SyntaxError: invalid syntax

# %%
df.dropna(subset=['Embarked'],inplace=True)
df1=df.drop(['PassengerId','Name','SibSp','Ticket','Cabin','Parch'],axis=1)
df1
# Out:
#      Survived  Pclass     Sex   Age      Fare Embarked
# 0           0       3    male  22.0    7.2500        S
# 1           1       1  female  38.0   71.2833        C
# 2           1       3  female  26.0    7.9250        S
# 3           1       1  female  35.0   53.1000        S
# 4           0       3    male  35.0    8.0500        S
# 5           0       3    male   NaN    8.4583        Q
# 6           0       1    male  54.0   51.8625        S
# 7           0       3    male   2.0   21.0750        S
# 8           1       3  female  27.0   11.1333        S
# 9           1       2  female  14.0   30.0708        C
# 10          1       3  female   4.0   16.7000        S
# 11          1       1  female  58.0   26.5500        S
# 12          0       3    male  20.0    8.0500        S
# 13          0       3    male  39.0   31.2750        S
# 14          0       3  female  14.0    7.8542        S
# 15          1       2  female  55.0   16.0000        S
# ...

# %%
x=df1.drop('Survived',axis=1)
y=df1['Survived']

# %%
x.head
# Out:
# <bound method NDFrame.head of      Pclass     Sex   Age      Fare Embarked
# 0         3    male  22.0    7.2500        S
# 1         1  female  38.0   71.2833        C
# 2         3  female  26.0    7.9250        S
# 3         1  female  35.0   53.1000        S
# 4         3    male  35.0    8.0500        S
# 5         3    male   NaN    8.4583        Q
# 6         1    male  54.0   51.8625        S
# 7         3    male   2.0   21.0750        S
# 8         3  female  27.0   11.1333        S
# 9         2  female  14.0   30.0708        C
# 10        3  female   4.0   16.7000        S
# 11        1  female  58.0   26.5500        S
# 12        3    male  20.0    8.0500        S
# 13        3    male  39.0   31.2750        S
# 14        3  female  14.0    7.8542        S
# 15        2  female  55.0   16.0000        S
# 16        3    male   2.0   29.1250        Q
# 17        2    male   NaN   13.0000        S
# 18        3  female  31.0   18.0000        S
# ...

# %%
y.head
# Out:
# <bound method NDFrame.head of 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64>

# %%
from sklearn.preprocessing import LabelEncoder
LabelEncoder
Leval=LabelEncoder()
x['Sex']=Leval.fit_transform(x['Sex'])
x['Embarked']=Leval.fit_transform(x['Embarked'])
x.head()
# Out:
#    Pclass  Sex   Age     Fare  Embarked
# 0       3    1  22.0   7.2500         2
# 1       1    0  38.0  71.2833         0
# 2       3    0  26.0   7.9250         2
# 3       1    0  35.0  53.1000         2
# 4       3    1  35.0   8.0500         2

# %%
df.dropna(subset=["Embarked"],inplace=True)
df1=df.drop(['Cabin','PassengerId','Name','SibSp', 'Parch','Ticket'],axis=1)
df1.shape
# Out:
# (889, 6)

# %%
df.dropna(subset=["Embarked"],inplace=True)
df1=df.drop(['Cabin','PassengerId','Name','SibSp', 'Parch','Ticket'],axis=1)
df1.shape
# Out:
# (889, 6)

# %%
from sklearn.preprocessing import LabelEncoder
Leval=LabelEncoder()
x['Sex']=Leval.fit_transform(x['Sex'])
x['Embarked']=Leval.fit_transform(x['Embarked'])
x.head()
# Out:
#    Pclass  Sex   Age     Fare  Embarked
# 0       3    1  22.0   7.2500         2
# 1       1    0  38.0  71.2833         0
# 2       3    0  26.0   7.9250         2
# 3       1    0  35.0  53.1000         2
# 4       3    1  35.0   8.0500         2

# %%
pclass=df.groupby('Pclass')

# %%
pclass['Age'].median()
# Out:
# Pclass
# 1    37.0
# 2    29.0
# 3    24.0
# Name: Age, dtype: float64

# %%
df['Age'].fillna("24")

# %%
x
# Out:
#      Pclass  Sex   Age      Fare  Embarked
# 0         3    1  22.0    7.2500         2
# 1         1    0  38.0   71.2833         0
# 2         3    0  26.0    7.9250         2
# 3         1    0  35.0   53.1000         2
# 4         3    1  35.0    8.0500         2
# 6         1    1  54.0   51.8625         2
# 7         3    1   2.0   21.0750         2
# 8         3    0  27.0   11.1333         2
# 9         2    0  14.0   30.0708         0
# 10        3    0   4.0   16.7000         2
# 11        1    0  58.0   26.5500         2
# 12        3    1  20.0    8.0500         2
# 13        3    1  39.0   31.2750         2
# 14        3    0  14.0    7.8542         2
# 15        2    0  55.0   16.0000         2
# 16        3    1   2.0   29.1250         1
# 18        3    0  31.0   18.0000         2
# 20        2    1  35.0   26.0000         2
# 21        2    1  34.0   13.0000         2
# 22        3    0  15.0    8.0292         1
# 23        1    1  28.0   35.5000         2
# ...

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
fill 24 where class 1 class 2 39 claas 3 34

# %%
fillna classwise
