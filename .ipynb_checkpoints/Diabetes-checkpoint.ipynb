# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
db=pd.read_csv("C:/Users/LENOVO/Downloads/diabetes.csv")
db
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
sns.boxplot(x='Glucose',y='BMI',data=db)
plt.show()

# %%
sns.scatterplot(x='Glucose',y='Age', data=db)
plt.show()

# %%
sns.violinplot(x='Glucose',data=db)
plt.show()

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(db, hue="BMI",size=10);
plt.show()
